# %%
# Cheese and Veggie Special
print('Hello. Welcome to our Sandwich Shop')
sandwich_type = input('"c" for Cheese or "v" for Veggie Special: ')
print()

if sandwich_type.lower() == 'c':
    print('Please select a cheese : ')
    cheese_type = input('"c" for Cheddar or "m" for Manchengo: ')
    
    if cheese_type.lower() == "c":
        print("Here is your Cheddar Cheese sandwich. Thank you.")
    elif cheese_type.lower() == "m":
        print("Here is your Manchego Cheese sandwich. Thank you.") 
    else:
        print("Sorry, we don't have", cheese_type, "choice today.")
        
elif sandwich_type.lower() == 'v':
    print("Here is your Vegetable sandwich. Thank you.")
    
else:
    print("Sorry, we don't have", sandwich_type, "choice today.")
    print()
    
print("Goodbye!")

# %%
# Program say 'Hello'

greeting_hello = input('Hello (y/n) : ')
if greeting_hello.lower() == 'y':
    print()
    
    hello_type = input('Hello or Hi : ')
    if hello_type.lower() == 'hello':
        print('HELLO')
    elif hello_type.lower() == 'hi':
        print('HI')
    else:
        print('Sorry, Greeting not recognized')
        
elif greeting_hello.lower() == 'n':
    print('FRIENDLY NOD')
    
else:
    print('That is not a greeting')

# %%
# Program 3 Guesses
bird_names = "Eagle, Hawk, Sparrow, Crow, Dove, Owl"
bird_guess = input('Guess the name of a bird ? ')

if bird_guess.title() in bird_names:
    print('Correct. It took you one try')
else:
    bird_guess = input('Guess the name of a bird ? ')
    
    if bird_guess.title() in bird_names:
        print('Correct. It took you two tries')
    else:
        bird_guess = input('Guess the name of a bird ? ')
        
        if bird_guess.title() in bird_names:
            print('Correct. It took you three tries') 
        else:
            print('Sorry. You are out of tries')
# Out:
# Guess the name of a bird ? hen
# Guess the name of a bird ? hen
# Guess the name of a bird ? hawk
# Correct. It took you three tries

# %%
# Program 3 Guesses
bird_names = "Eagle, Hawk, Sparrow, Crow, Dove, Owl"
bird_guess = input('Guess the name of a bird ? ')

if bird_guess in bird_names == False:
    bird_guess = input('Guess the name of a bird ? ')
else:
    print('Correct. It took you one try')
# Out:
# Guess the name of a bird ? hen
# Correct. It took you one try

# %%
# Newline
print('Good Morning\nGuten Morgen')

# %%
player_number = 8
player_name = 'Juan Mata'
print('PLAYER NAME\tNumber')
print(player_name,'\t',player_number)

# %%
#Quotes
print('\'quotes\'')
print("I\'ve said \"save your notebook\" so just do it")

# %%
print ("\\\WARNING!///")

# %%
print('One\tTwo\tThree\nFour\tFive\tSix')

# %%
print(" \"What's that\" ")

# %%
print("Hello" + '\n' + "World!")

# %%
while True:
    print('Hello')
    break

# %%
number_guess = '0'
secret_number = '5'

while True:
    number_guess = input('Guess a number (1 to 5) : ')
    if number_guess == secret_number:
        print(number_guess,'is correct')
        break
    else:
        print(number_guess,'is incorrect')

# %%
while True:
    fname = input('Enter your first name only : ')
    if fname.isalpha():
        break
    else:
        print(fname,'isnot a single word')
        
print(fname,'knows how to follow instructions')

# %%
while True:
    weather = input("Enter weather (sunny, rainy, snowy, or quit): ") 
    print()

    if weather.lower() == "sunny":
        print("Wear a t-shirt and sunscreen")
        break
    elif weather.lower() == "rainy":
        print("Bring an umbrella and boots")
        break
    elif weather.lower() == "snowy":
        print("Wear a warm coat and hat")
        break
    elif weather.lower().startswith("q"):
        print('"quit" detected, exiting')
        break
    else:
        print("Sorry, not sure what to suggest for", weather +"\n")

# %%
familiar_name = ""
while True:
    familiar_name = input('State a common name : ')
    if familiar_name == "":
        break
    else:
        print('Hello',familiar_name,'\n')

# %%
votes = 3

votes = votes + 1
print(votes)
# Out:
# 4

# %%
votes += 2
print(votes)
# Out:
# 6

# %%
seat_count = 0
while True:
    print('seat count',seat_count)
    seat_count = seat_count + 1
    
    if seat_count > 4:
        break
# Out:
# seat count 0
# seat count 1
# seat count 2
# seat count 3
# seat count 4

# %%
seat_count = 0
soft_seats = 0
hard_seats = 0
num_seats = 4

while True:

    seat_type = input('enter type of seat "hard", "soft" or "exit" (or finish) : ')
    if seat_type.lower().startswith('e'):
        print()
        break

    elif seat_type.lower() == 'hard':
        hard_seats += 1
    elif seat_type.lower() == 'soft':
        soft_seats += 1
    else:
        print('Invalid entry: counted as hard')
        hard_seats += 1
    seat_count += 1

    if seat_count >= num_seats:
        print('\nseats are full')
        break
# Out:
# enter type of seat "hard", "soft" or "exit" (or finish) : soft
# enter type of seat "hard", "soft" or "exit" (or finish) : soft
# enter type of seat "hard", "soft" or "exit" (or finish) : soft
# enter type of seat "hard", "soft" or "exit" (or finish) : soft
#
# seats are full

# %%
# initialize variables
seat_count = 0
soft_seats = 0
hard_seats = 0
num_seats = 4

# loops tallying seats using soft pads vs hard, until seats full or user "exits"
while True:
    seat_type = input('enter seat type of "hard","soft" or "exit" (to finish): ')
    
    if seat_type.lower().startswith("e"):
        print()
        break
    elif seat_type.lower() == "hard":
        hard_seats += 1
    elif seat_type.lower() == "soft":
        soft_seats += 1
    else:
        print("invalid entry: counted as hard")
        hard_seats += 1  
    seat_count += 1
    if seat_count >= num_seats:
        print("\nseats are full")
        break
        
print(seat_count,"Seats Total: ",hard_seats,"hard and",soft_seats,"soft" )
# Out:
# enter seat type of "hard","soft" or "exit" (to finish): hard
# enter seat type of "hard","soft" or "exit" (to finish): easy
#
# 1 Seats Total:  1 hard and 0 soft

# %%
# Program Shirt Count

def shirtprog(): 
    small_size = 0
    medium_size = 0
    large_size = 0
    shirt_total = 4
    shirt_count = 0
    
    small_price = 6
    medium_price = 7
    large_price = 8


    while True:
        shirt_type = input('Enter shirt type "small", "medium", "large" or "exit" (to finish)  : ')
        if shirt_type.lower().startswith('e'):
            print()
            break     
        elif shirt_type.lower() == 'small':
            small_size += 1
        elif shirt_type.lower() == 'medium':
            medium_size += 1
        elif shirt_type.lower() == 'large':
            large_size += 1
        else:
            print('Invalid Entry')

        shirt_count += 1
        if  shirt_count >= shirt_total:
            print('\nWe are out of stock')
            break

    print(shirt_count,"Shirt Total: ",small_size,"small and",medium_size,"medium and",large_size,'large' )
    print('Small size costs',small_size * small_price,'Medium size costs',medium_size * medium_price,'Large size costs',large_size * large_price)
    print('Total cost is',(small_size * small_price) + (medium_size * medium_price) + (large_size * large_price))

# %%
shirtprog()
# Out:
# Enter shirt type "small", "medium", "large" or "exit" (to finish)  : small
# Enter shirt type "small", "medium", "large" or "exit" (to finish)  : small
# Enter shirt type "small", "medium", "large" or "exit" (to finish)  : small
# Enter shirt type "small", "medium", "large" or "exit" (to finish)  : large
#
# We are out of stock
# 4 Shirt Total:  3 small and 0 medium and 1 large
# Small size costs 18 Medium size costs 0 Large size costs 8
# Total cost is 26

# %%
greet_count = 5

# loop while count is greater than 0
while greet_count > 0:
    print(greet_count, "!")
    greet_count -= 1
print("\nIGNITION!")
# Out:
# 5 !
# 4 !
# 3 !
# 2 !
# 1 !
#
# IGNITION!

# %%
seat_count = 0

while seat_count <= 4:
    print('seat count',seat_count)
    seat_count = seat_count + 1
# Out:
# seat count 0
# seat count 1
# seat count 2
# seat count 3
# seat count 4

# %%
# Sandwich Order Shop
print('Welcome to our Sandwich shop.\nWe have the Cheese Special and the Veggie Special')
sandwich_type = input('"c" for Cheese or "v" for Veggie Special: ')
if sandwich_type.lower() == 'c':
    cheese_type = input('"c" for Cheddar or "m" for Manchengo: ')
    if cheese_type.lower() == 'c':
        print('Here is your Cheddar Cheese Sandwich')
    elif cheese_type.lower() == 'm':
        print('Here is your Manchengo Cheese Sandwich')
    else:
        print("Sorry, we don't have", cheese_type, "choice today.")
elif sandwich_type.lower() == 'v':
    print('Here is your Veggie Sandwich')
else:
    print("Sorry, we don't have", sandwich_type, "choice today.")
    
print()
print('Goodbye!')
# Out:
# Welcome to our Sandwich shop.
# We have the Cheese Special and the Veggie Special
# "c" for Cheese or "v" for Veggie Special: c
# "c" for Cheddar or "m" for Manchengo: c
# Here is your Cheddar Cheese Sandwich
#
# Goodbye!

# %%
# Greetings Program
greet_person = input('Say "Hello" (y/n): ')

if greet_person.lower() == 'y':
    hello_type = input('"Hello" or "Hi" (y/n): ')
    if hello_type.lower() == 'y':
        print('HELLO!')
    elif hello_type.lower() == 'n':
        print('HI!')
    else:
        print('Wamlambez!')
elif greet_person.lower() == 'n':
    print('Friendly Nod')
else:
    print('Wamlambez!')
# Out:
# Say "Hello" (y/n): hjjk
# Wamlambez!

# %%
# Program Bird Guess
bird_names = ('Hawk, Eagle, Owl, Dove')
bird_guess = input('Guess the name of a bird: ')

if bird_guess.title() in bird_names:
    print()
    print('Congratulations!!!\nIt took you only one try')
else:
    bird_guess = input('Guess the name of a bird: ')
    
    if bird_guess.title() in bird_names:
        print()
        print('Congratulations!!!\nIt took you two tries')
    else:
        bird_guess = input('Guess the name of a bird: ')
    
        if bird_guess.title() in bird_names:
            print()
            print('Correct\nIt took you three tries')
        else:
            print('You are out of tries.\nBetter luck next time.')
# Out:
# Guess the name of a bird: cow
# Guess the name of a bird: cow
# Guess the name of a bird: hawk
#
# Correct
# It took you three tries

# %%
print('Hello World \nHello another world')
# Out:
# Hello World
# Hello another world

# %%
tries = 3
while tries >= 1:
    tries = tries - 1
    print('You have',tries,'left')
# Out:
# You have 2 left
# You have 1 left
# You have 0 left

# %%
student_name = 'Mark Kaharo'
student_age = 23

print('STUDENT NAME','\t','STUDENT AGE')
print(student_name,'\t',student_age)
# Out:
# STUDENT NAME 	 STUDENT AGE
# Mark Kaharo 	 23

# %%
print("He said \"I\'ve not done the task yet\"")
# Out:
# He said "I've not done the task yet"

# %%
print("for a newline use \\n")
# Out:
# for a newline use \n

# %%
print("\\\WARNING!///")
# Out:
# \\WARNING!///

# %%
print("\"What\'s that?\" isn\'t a specific question")
# Out:
# "What's that?" isn't a specific question

# %%
print("One \t Two \t Three \nFour \t Five \t Six")
# Out:
# One 	 Two 	 Three
# Four 	 Five 	 Six

# %%
print("Hello" + '\n' + "World!")
# Out:
# Hello
# World!

# %%
# Program Pre Word
def pre_word(s):
    s = s.lower()
    if s.startswith('pre'):
        return True
    else:
        return False
    
    if s.isalpha():
        return True
    else:
        return False

# %%
entry = input('Enter a word that starts with "pre": ')
value = pre_word(entry)

if value == False:
    print('That is not a valid "pre" word!')
else:
    print('That is a valid "pre" word')
# Out:
# Enter a word that starts with "pre": prepare
# That is a valid "pre" word

# %%
ger = "Guten Morgen"
eng = " Good Morning"

while True:
    print(eng,'\n',ger)
# Out:
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
#  Good Morning
#  Guten Morgen
# ...

# %%
while True:
    print('Print forever unless there is a break')
    break
# Out:
# Print forever unless there is a break

# %%
# Program number game 
secret_number = 5
while True:
    number_guess = input('Guess a number from 1-10: ')
    if number_guess.isdigit():
        if int(number_guess) == secret_number:
            print('Good Job')
            break
        else:
            print('Try Again')
    else:
        print('Please enter a digit')
# Out:
# Guess a number from 1-10: k
# Please enter a digit
# Guess a number from 1-10: k
# Please enter a digit
# Guess a number from 1-10: l
# Please enter a digit
# Guess a number from 1-10: jhjh
# Please enter a digit
# Guess a number from 1-10: 5lk
# Please enter a digit
# Guess a number from 1-10: 5
# Good Job

# %%
# Number Guess Game
initial = 5
def number_guess(guess):
    while True:
        if guess.isdigit():
            if int(guess) == initial:
                print('Good Job')
                return True
            else:
                print('Try Again')
                return False
        else:
            print('Please enter a digit')
            return False

# %%
tries = 3
gue_num = input('Guess a number between 1-10: ')
value = number_guess(gue_num)

while value == False and tries >= 1:
    gue_num = input('Guess a number between 1-10: ')
    number_guess(gue_num)
    tries = tries - 1
    print('You have',tries,'left')
# Out:
# Guess a number between 1-10: 5
# Good Job

# %%
# Clothes suggestion
while True:
    weather = input('What is the weather today (sunny, snowy, rainy or quit): ')
    print()
    
    if weather.lower() == "sunny":
        print("Wear a t-shirt and sunscreen")
        break
    elif weather.lower() == "rainy":
        print("Bring an umbrella and boots")
        break
    elif weather.lower() == "snowy":
        print("Wear a warm coat and hat")
        break
    elif weather.lower().startswith("q"):
        print('"quit" detected, exiting')
        break
    else:
        print("Sorry, not sure what to suggest for", weather +"\n")
# Out:
# What is the weather today (sunny, snowy, rainy or quit): windy
#
# Sorry, not sure what to suggest for windy
#
# What is the weather today (sunny, snowy, rainy or quit): cloudy
#
# Sorry, not sure what to suggest for cloudy
#
# What is the weather today (sunny, snowy, rainy or quit): snowy
#
# Wear a warm coat and hat

# %%
# Get name program
familiar_name = ''
while True:
    familiar_name = input('Enter a common name: ')
    if familiar_name == '' or familiar_name.isalpha() == True:
        print('Greetings',familiar_name)
        break
    else:
        print("That's not a familiar name")
# Out:
# Enter a common name: 3244
# That's not a familiar name
# Enter a common name: 484
# That's not a familiar name
# Enter a common name: neg-gjh
# That's not a familiar name
# Enter a common name: Carlton
# Greetings Carlton

# %% [markdown]
# INCREMENT AND DECREMENT

# %%
# Increment
seat_count = 0
while True:
    print('Seat count =',seat_count)
    seat_count = seat_count + 1
    
    if seat_count >= 5:
        print('No more seats available')
        break
# Out:
# Seat count = 0
# Seat count = 1
# Seat count = 2
# Seat count = 3
# Seat count = 4
# No more seats available

# %%
# Decrement

seat_count = 5

while True:
    print('Remaining seats =',seat_count)
    seat_count -= 1
    
    if seat_count <= 0:
        print('No seats left')
        break
# Out:
# Remaining seats = 5
# Remaining seats = 4
# Remaining seats = 3
# Remaining seats = 2
# Remaining seats = 1
# No seats left

# %%
seat_count = 0
soft_seats = 0
hard_seats = 0
num_seats = 4

# loops tallying seats using soft pads vs hard, until seats full or user "exits"
while True:
    seat_type = input('enter seat type of "hard","soft" or "exit" (to finish): ')
    
    if seat_type.lower().startswith("e"):
        print()
        break
    elif seat_type.lower() == "hard":
        hard_seats += 1
    elif seat_type.lower() == "soft":
        soft_seats += 1
    else:
        print("invalid entry: counted as hard")
        hard_seats += 1  
    seat_count += 1
    if seat_count >= num_seats:
        print("\nseats are full")
        break
        
print(seat_count,"Seats Total: ",hard_seats,"hard and",soft_seats,"soft" )
# Out:
# enter seat type of "hard","soft" or "exit" (to finish): h
# invalid entry: counted as hard
# enter seat type of "hard","soft" or "exit" (to finish): hard
# enter seat type of "hard","soft" or "exit" (to finish): soft
# enter seat type of "hard","soft" or "exit" (to finish): soft
#
# seats are full
# 4 Seats Total:  2 hard and 2 soft

# %%
# Program Shirt Count
small_size = 0
small_cost = 6
medium_size = 0
medium_cost = 7
large_size = 0
large_cost = 8

while True:
    shirt_size = input('Enter your shirt size (S,M,L) or "exit" to quit: ')
    if shirt_size.lower() == 's':
        small_size += 1
        
    elif shirt_size.lower() == 'm':
        medium_size += 1
        
    elif shirt_size.lower() == 'l':
        large_size += 1
        
    elif shirt_size.lower() == 'e':
        break
        
    else:
        print('Invalid entry. Counted as Large')
        large_size += 1
        
small_price = small_size * small_cost
medium_price = medium_size * medium_cost
large_price = large_size * large_cost
        
print()
print('TYPE\tCOUNT\tPRICE','\nSmall \t',small_size,'\t$',small_price,'\nMedium \t',medium_size,'\t$',medium_price,'\nLarge \t',large_size,'\t$',large_price)
# Out:
# Enter your shirt size (S,M,L) or "exit" to quit: s
# Enter your shirt size (S,M,L) or "exit" to quit: s
# Enter your shirt size (S,M,L) or "exit" to quit: s
# Enter your shirt size (S,M,L) or "exit" to quit: m
# Enter your shirt size (S,M,L) or "exit" to quit: m
# Enter your shirt size (S,M,L) or "exit" to quit: m
# Enter your shirt size (S,M,L) or "exit" to quit: k
# Invalid entry. Counted as Large
# Enter your shirt size (S,M,L) or "exit" to quit: k
# Invalid entry. Counted as Large
# Enter your shirt size (S,M,L) or "exit" to quit: k
# Invalid entry. Counted as Large
# Enter your shirt size (S,M,L) or "exit" to quit: e
#
# TYPE	COUNT	PRICE
# Small 	 3 	$ 18
# Medium 	 3 	$ 21
# Large 	 3 	$ 24

# %% [markdown]
# Boolean While Loop

# %%
seat_count = 5
while seat_count > 0:
    print('Remaining seats -',seat_count)
    seat_count -= 1
    
print()
print('Endea kiti OML 5')
# Out:
# Remaining seats - 5
# Remaining seats - 4
# Remaining seats - 3
# Remaining seats - 2
# Remaining seats - 1
#
# Endea kiti OML 5

# %%
# Program Animal Names
num_animals = 0
all_animals = []

while num_animals < 4:
    animal_name = input('Enter the name of an animal: ')
    num_animals += 1
    all_animals.append(animal_name)
    
    if animal_name.lower() == 'exit':
        all_animals.remove('exit')
        print('Game Over')
        break
    else:
        pass


print()
print(all_animals)
# Out:
# Enter the name of an animal: goat
# Enter the name of an animal: lion
# Enter the name of an animal: sheep
# Enter the name of an animal: cow
#
# ['goat', 'lion', 'sheep', 'cow']

# %%
count = 1

# loop 5 times
while count < 6:
    print(count, "x", count, "=", count*count)
    count +=1
# Out:
# 1 x 1 = 1
# 2 x 2 = 4
# 3 x 3 = 9
# 4 x 4 = 16
# 5 x 5 = 25

# %%
# Program Long Number

int_num = input('Enter a number: ')
long_num = ''

while int_num.isdigit() == True:
    long_num = long_num + int_num
    int_num = input('Enter a number: ')
    
print(long_num)
# Out:
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: 4
# Enter a number: y
# 4444444444444444

# %% [markdown]
# MODULE 4 PRACTICE - NOTEBOOK 6

# %%
# [ ] print a string that outputs the following exactly: The new line character is "\n"
print('The new line character is "\\n"')
# Out:
# The new line character is "\n"

# %%
# [ ] print output that is exactly (with quotes): "That's how we escape!"
print('\"That\'s how we escape!\"')
# Out:
# "That's how we escape!"

# %%
# [ ] with only 1 print statement and using No Space Characters, output the text commented below  

# 1       one
# 22      two
# 333     three

print('# 1 \t one \n# 22 \t two \n# 333 \t three')
# Out:
# # 1 	 one
# # 22 	 two
# # 333 	 three

# %%
'''Program: quote_me() Function
quote_me takes a string argument and returns a string that will display surrounded with added double quotes if printed

check if passed string starts with a double quote ("\""), then surround string with single quotations
if the passed string starts with single quote, or if doesn't start with a quotation mark, then surround with double quotations
Test the function code passing string input as the argument to quote_me()

# [ ] create and test quote_me()'''
# Out:
# 'Program: quote_me() Function\nquote_me takes a string argument and returns a string that will display surrounded with added double quotes if printed\n\ncheck if passed string starts with a double quote ("""), then surround string with single quotations\nif the passed string starts with single quote, or if doesn\'t start with a quotation mark, then surround with double quotations\nTest the function code passing string input as the argument to quote_me()\n\n# [ ] create and test quote_me()'

# %%
# Program quote_me

def quote_me(string):
    if string.startswith("\""):
        string = '' + string + ''
    else:
        string = '\"' + string + '\"'
        
    final_string = '\"' + string + '\"'
    return final_string

# %%
comment = input('Say something: ')
quote_me(comment)
# Out:
# Say something: "Hello"
# '""Hello""'

# %%
# Program Shirt Order
shirt_color = input('What color would you like? ')
shirt_size = input('What is your shirt size (S,M,L)? ')

available = False
if shirt_color.lower() == 'white':
    
    if shirt_size.upper() == 'L':
        available = True
    elif shirt_size.upper() == 'M':
        available = True
    else:
        available = False
        
elif shirt_color.lower() == 'blue':
    if shirt_size.upper() == 'M':
        available = True
    elif shirt_size.upper() == 'S':
        available = True
    else:
        available = False
        
else:
    print()
    print('Sorry, We do not have it in stock'.upper())
    
  

print()
print('COLOR\tSIZE\tAVAILABILITY \n' + shirt_color + '\t' + shirt_size.upper() + '\t' + str(available))
# Out:
# What color would you like? white
# What is your shirt size (S,M,L)? l
#
# COLOR	SIZE	AVAILABILITY
# white	L	True

# %%
# String Analysis Program

def str_analysis(string):
    if string.isdigit():
        string = int(string)
        if string > 99:
            print('That is a big number')
        else:
            print('That is a small number')
    else:
        if string.isalpha():
            print('Alphabetical characters')
        else:
            print('Neither alphabetical nor numerical')

# %%
entry = input('Enter something: ')
str_analysis(entry)
# Out:
# Enter something: lkgkgklg.
# Neither alphabetical nor numerical

# %% [markdown]
# Program: ticket_check() - finds out if a seat is avaiable
# Call ticket_check() function with 2 arguments: section and seats requested and return True or False
#
# section is a string and expects: general, floor
# seats is an integer and expects: 1 - 10
# Check for valid section and seats
#
# if section is general (or use startswith "g")
# if seats is 1-10 return True
# if section is floor (or use starts with "f")
# if seats is 1-4 return True
# otherwise return False
#
# # [ ] create and call ticket_check()

# %%
def ticket_check(section,seats):
    if section.isdigit() == True:
        print('Please use the correct input')
    elif seats.isdigit() == False:
        print('Please use the correct input')
    else:
        seats = int(seats)
        if section.lower().startswith('g'):
            if seats in range(1,11):
                return True
            else:
                return False
        elif section.lower().startswith('f'):
            if seats in range(1,5):
                return True
            else:
                return False
        else:
            print('Sorry')

# %%
sec = input('Please enter your preffered section "General" or "Floor": ')
sea = input('Please enter number of seats (1-10): ')
ticket_check(sec,sea)
# Out:
# Please enter your preffered section "General" or "Floor": floor
# Please enter number of seats (1-10): 4
# True

# %% [markdown]
# MODULE 4 PRACTICE - NOTEBOOK 7

# %%
# [ ] use a "forever" while loop to get user input of integers to add to sum, 
# until a non-digit is entered, then break the loop and print sum
# sum = 0

sum = 0
while True:
    entry = input('Enter a number: ')
    
    if entry.isdigit():
        sum = sum + int(entry)
    else:
        break
     
print()
print(sum)
# Out:
# Enter a number: 5
# Enter a number: 4
# Enter a number: 2
# Enter a number: l
#
# 11

# %%
tickets = input("enter tickets remaining (0 to quit): ")
tickets = int(tickets)

while tickets > 0:
        # if tickets are multiple of 3 then "winner"
    if int(tickets/3) == tickets/3:
        print("you win!")
        break
    else:
        print("sorry, not a winner.")

print("Game ended")
# Out:
# enter tickets remaining (0 to quit): 12
# you win!
# Game ended

# %%
# [ ] use a while True loop (forever loop) to give 4 chances for input of a correct color in a rainbow
# rainbow = "red orange yellow green blue indigo violet"

tries = 4
rainbow = "red, orange, yellow, green, blue, indigo, violet"
while True:
    entry = input('Enter a color found on the rainbow: ')
    if entry.lower() in rainbow:
        print('Good Job. You have',tries,'left')
        break
    else:
        tries -=1
        if tries < 1:
            print('sorry, you have',tries,'left')
            break
# Out:
# Enter a color found on the rainbow: blackish
# Enter a color found on the rainbow: house
# Enter a color found on the rainbow: redding
# Enter a color found on the rainbow: bluing
# sorry, you have 0 left

# %%
# [ ] Get input for a book title, keep looping while input is Not in title format (title is every word capitalized)
title = ""

while title.istitle() == False:
    entry = input('Enter a text: ')
    if entry.istitle() == True:
        break

print(entry)
# Out:
# Enter a text: tdat
# Enter a text: hello
# Enter a text: james
# Enter a text: James Rodrighuez
# James Rodrighuez

# %%
# [ ] create a math quiz question and ask for the solution until the input is correct

while True:
    entry1 = input('Enter a number: ')
    entry2 = input('Enter a number: ')
    entry_sum = entry1 + entry1
    
    if entry_sum == entry1 + entry2:
        break
# Out:
# Enter a number: 6
# Enter a number: 5
# Enter a number: 6
# Enter a number: 0
# Enter a number: 0
# Enter a number: 0

# %% [markdown]
# quiz_item()has 2 parameter strings: question and solution
# shows question, gets answer input
# returns True if answer == solution or continues to ask question until correct answer is provided
# use a while loop
# create 2 or more quiz questions that call quiz_item()
# Hint: provide multiple choice or T/F answers
#
# # Create quiz_item() and 2 or more quiz questions that call quiz_item()

# %%
def quiz_item(question,solution):
    answer = input(question)
    if answer.lower() == solution.lower():
        return True
    else:
        return False

# %%
quest = 'Who is the president of Kenya? '
sol = 'Uhuru'

value = quiz_item(quest,sol)
tries = 1

while value == False:
    tries +=1
    value = quiz_item(quest,sol)
    if value == True:
        break
    else:
        pass
    
if tries == 1:
    print('It took you',tries,'try')
else:
    print('It took you',tries,'tries')
# Out:
# Who is the president of Kenya? Uhunye
# Who is the president of Kenya? dhdhd
# Who is the president of Kenya? dhdd
# Who is the president of Kenya? shfdhfb
# Who is the president of Kenya? 6565
# Who is the president of Kenya? mdkvidfn
# Who is the president of Kenya? fndfbdf
# Who is the president of Kenya? dfbdjjfbufb
# Who is the president of Kenya? sfhdfbufb
# Who is the president of Kenya? sfbdjfbudfb
# Who is the president of Kenya? sfnjfbfb
# Who is the president of Kenya? dnfbsbs
# Who is the president of Kenya? dhfudbsid'dfbsd
# Who is the president of Kenya? dbfjbksdn
# Who is the president of Kenya? sfbskbskdn
# Who is the president of Kenya? ssfnskbsjdb
# Who is the president of Kenya? fndkfbkb
# Who is the president of Kenya? nfdkfbjdfb
# Who is the president of Kenya? uhuru
# It took you 19 tries

# %% [markdown]
# FINAL PROJECT

# %%
# Program Adding Report

def adding_report(rep_type = 'T'):
    total = 0
    items = ''
    while True:      
        if rep_type.upper() == 'T':
            t_rep = input('Input an integer to add to the total or "Q" to quit ')
            if t_rep.lower() == 'q':
                print('You have chosen to quit')
                break
            elif t_rep.isdigit():
                t_rep = int(t_rep)
                total = total + t_rep
            else:
                print(t_rep,'is invalid input')
                
            print('')
            print('Total \n ' + str(total))
                  
        elif rep_type.upper() == 'A':
            a_rep = input('Input an integer to add to the total or "Q" to quit ')
            if a_rep.lower() == 'q':
                print('You have chosen to quit')
                break
                
            elif a_rep.isdigit():
                items = items + '\n' + a_rep
                a_rep = int(a_rep)
                total = total + a_rep
                
            else:
                print(a_rep,'is invalid input')
                
        elif rep_type == '':
            t_rep = input('Input an integer to add to the total or "Q" to quit ')
            if t_rep.lower() == 'q':
                print('You have chosen to quit')
                break
            elif t_rep.isdigit():
                t_rep = int(t_rep)
                total = total + t_rep
            else:
                print(t_rep,'is invalid input')    
        
        else:
            print(rep_type,'is invalid input')
            break
            
    if rep_type.upper() == '':
        print()
        print(' Total \n ' + str(total))
    elif rep_type.upper == 'T':
        print('')
        print(' Total \n ' + str(total))
    elif rep_type.upper() == 'A':
        print('.....OUTPUT.....')
        print('Items\n ',items)
        print()
        print(' Total \n ' + str(total))

# %%
entry = input('Choose Report Type ("A" or "T"): ')
adding_report(entry)
# Out:
# Choose Report Type ("A" or "T"): T
# Input an integer to add to the total or "Q" to quit 2
#
# Total
#  2
# Input an integer to add to the total or "Q" to quit 4
#
# Total
#  6
# Input an integer to add to the total or "Q" to quit 8
#
# Total
#  14
# Input an integer to add to the total or "Q" to quit d
# d is invalid input
#
# Total
#  14
# Input an integer to add to the total or "Q" to quit g
# g is invalid input
#
# Total
#  14
# Input an integer to add to the total or "Q" to quit f
# f is invalid input
#
# Total
#  14
# Input an integer to add to the total or "Q" to quit q
# You have chosen to quit
